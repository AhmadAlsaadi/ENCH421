# %% [markdown]
# ### Problem No. 1
# Find the Laplace transforms of the following functions:
# 1. $f(t)=5+e^{-3t}+te^{-4t}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. $f(t)=sin(4t)+(t-3)S(t-3)+e^{-(t-3)}S(t-3)+\frac{5}{t}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. $f(t)=e^{-t}cos(4t)+\frac{t}{5}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. $f(t)=S(t-1)cos(4(t-1))+t^2$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Problem No. 2
# Derive Laplace transforms of the input signals shown below
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Problem No. 3
# find x(t) for:
# 1. $X(s)=\large{\frac{s(s+1)}{(s+2)(s+3)(s+4)}}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. $X(s)=\large{\frac{(s+2)}{(s+1)^2}}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. $X(s)=\large{\frac{1}{s^2+s+1}}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. $X(s)=\large{\frac{s+1}{s(s+4)(s+3)}e^{-0.5t}}$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Problem No. 4
# For the integro-differential equation,
# $$\frac{d^2x}{dt}+4\frac{dx}{dt}+3x=2\int^t_0{e^{-t}}dt\\
# \text{with}\quad \frac{dx}{dt}(0)=x(0)=0$$
# 1. find x(t)?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. What is the limiting value of t as t $\to \infty$?

# %% [markdown]
# ![image.png](attachment:image.png)
